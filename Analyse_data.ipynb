# %% [markdown]
# <a href="https://colab.research.google.com/github/CakeNuthep/Create_Knowledge_Graph/blob/main/Analyse_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_acthor_tagged = pd.read_csv('/content/drive/MyDrive/SuperAI/Knowledge Graph/Dataset/author-tagged.csv')
df_data_combine = pd.read_excel('/content/drive/MyDrive/SuperAI/Knowledge Graph/Dataset/DataCombine_version2.xlsx','วิเคราะห์')

# %%
df_acthor_tagged
# Out:
#                           Tname                      Ename
# 0             สุรีย์พร กฤษเจริญ      Sureeporn Kritcharoen
# 1              อรอนงค์ ดอกจันรี
# 2             วีรศักดิ์ ฟองเงิน          Weerasak Fongngen
# 3             สุรพงษ์ เพ็ชร์หาญ           Surapong Petharn
# 4                 ชัยวุฒิ โกเมศ              Chaivut Komez
# ...                         ...                        ...
# 203824    สุจิตรา ชัยกิตติศิลป์     Suchitra Chaikittisilp
# 203825           ดวงใจ ลิมตโสภณ        Duangjai Limtasopon
# 203826          อังสนา ศิรประชา        Aungsana Sirapracha
# 203827       บุบผา วิริยรัตนกุล     Buppar Viriyaratanakul
# 203828  แสงทอง เลิศประเสริฐพงศ์  Sangthong Lertprasertpong
#
# [203829 rows x 2 columns]

# %%
df_data_combine
# Out:
#       Unnamed: 0  ...                                 อ้างอิง (เว็บไซต์)
# 0            NaN  ...  http://eng.pnu.ac.th/web/academic-staffs/hafis...
# 1            NaN  ...  http://eng.pnu.ac.th/web/academic-staffs/asst-...
# 2            NaN  ...  http://eng.pnu.ac.th/web/academic-staffs/hasun...
# 3            NaN  ...  http://eng.pnu.ac.th/web/academic-staffs/hassa...
# 4            NaN  ...                                                NaN
# ...          ...  ...                                                ...
# 7299         NaN  ...  https://www.krai.io/people,https://set.ait.ac....
# 7300         NaN  ...  https://repository.nida.ac.th/handle/662723737...
# 7301         NaN  ...  https://pdfs.semanticscholar.org/be4e/ef39fc48...
# 7302         NaN  ...  http://www.eng.au.edu/index.php/about/faculty-...
# 7303         NaN  ...                  https://me.eng.cmu.ac.th/staff/47
#
# [7304 rows x 24 columns]

# %%
last_name_index = 8
last_name = df_data_combine.columns[last_name_index]
first_name_index = 7
first_name = df_data_combine.columns[first_name_index]

# %%
df_data_combine[first_name] = df_data_combine[first_name].str.upper() 
df_data_combine[last_name] = df_data_combine[last_name].str.upper()

# %% [markdown]
# # วิเคราะห์เรื่องการ Duplicate ข้อมูล

# %%
def get_count(values):
    return len(values)

# %%
grouped_count = df_data_combine.groupby(last_name).agg(get_count)

# %%
grouped_count
# Out:
#                        Unnamed: 0  ...  อ้างอิง (เว็บไซต์)
# Last name                          ...
# -                          1072.0  ...                1072
# A. BAY                        1.0  ...                   1
# A. HIPSHER                    1.0  ...                   1
# ABDEL RAHMAN TAWALBEH         1.0  ...                   1
# ABDULLAH                      1.0  ...                   1
# ...                           ...  ...                 ...
# YUTTHASARNSENEE               1.0  ...                   1
# YUVAPOOSITANON                1.0  ...                   1
# YUWAKOSOL                     1.0  ...                   1
# ZHAO                          1.0  ...                   1
# ๋JANTIMA                      1.0  ...                   1
#
# [5749 rows x 23 columns]

# %%
grouped_count = df_data_combine.groupby(first_name).agg(get_count)

# %%
grouped_count
# Out:
#              Unnamed: 0  Unnamed: 1  ...  ความเชี่ยวชาญ  อ้างอิง (เว็บไซต์)
# First name                           ...
# -                1033.0        1033  ...           1033                1033
# ABDULFATTAH         1.0           1  ...              1                   1
# ABHISITH            1.0           1  ...              1                   1
# ABIDENG             1.0           1  ...              1                   1
# ACHANAI             1.0           1  ...              1                   1
# ...                 ...         ...  ...            ...                 ...
# ‪THINNAPHAT         1.0           1  ...              1                   1
# ‪VITTHAYA           1.0           1  ...              1                   1
# ‪WANCHAI            1.0           1  ...              1                   1
# ‪WANVIMOL           1.0           1  ...              1                   1
# ‪WIPHUSANA          1.0           1  ...              1                   1
#
# ...

# %%
grouped_count = df_data_combine.groupby([first_name,last_name]).agg(get_count)

# %%
grouped_count
# Out:
#                              Unnamed: 0  ...  อ้างอิง (เว็บไซต์)
# First name  Last name                    ...
# -           -                    1033.0  ...                1033
# ABDULFATTAH MASAMEA                 1.0  ...                   1
# ABHISITH    DOEMSUNTIA              1.0  ...                   1
# ABIDENG     HAWA                    1.0  ...                   1
# ACHANAI     BUASRI                  1.0  ...                   1
# ...                                 ...  ...                 ...
# ‪THINNAPHAT BORIRAK                 1.0  ...                   1
# ‪VITTHAYA   PHANCHAROENSINN         1.0  ...                   1
# ‪WANCHAI    CHANKAIPOL              1.0  ...                   1
# ‪WANVIMOL   NADEE                   1.0  ...                   1
# ‪WIPHUSANA  CHAYINTHU               1.0  ...                   1
#
# [6051 rows x 22 columns]

# %%
duplicate_name = df_data_combine.duplicated([first_name,last_name])

# %%
df_duplicate_name = df_data_combine[duplicate_name]

# %%
df_duplicate_name
# Out:
#       Unnamed: 0  ...                                 อ้างอิง (เว็บไซต์)
# 36           NaN  ...           https://ict.up.ac.th/personnel/major/ice
# 42           NaN  ...  https://baac.reru.ac.th/index.php?option=com_c...
# 46           NaN  ...              https://finearts.dpu.ac.th/staff/3/20
# 47           NaN  ...  http://www.mct.rmutt.ac.th/aboutus/personnel-n...
# 51           NaN  ...  http://idt.pnru.ac.th/index.php?op=detail&opid...
# ...          ...  ...                                                ...
# 7185         1.0  ...                                                NaN
# 7186         NaN  ...            https://ict.up.ac.th/personnel/major/cs
# 7189         NaN  ...  http://www.eng2.su.ac.th/department_industrial...
# 7208         NaN  ...     http://bba.ubru.ac.th/web/person.php?tid=11#r2
# 7270         NaN  ...  https://scholar.google.com/citations?user=xsYO...
#
# [1253 rows x 24 columns]

# %%
df_duplicate_name.to_csv('duplicate_name.csv')

# %%
duplicate_and_duplicate_name = df_duplicate_name.duplicated([first_name,last_name])

# %%
df_duplicate_and_duplicate_name = df_duplicate_name[duplicate_and_duplicate_name == False]

# %%
df_duplicate_and_duplicate_name
# Out:
#       Unnamed: 0  ...                                 อ้างอิง (เว็บไซต์)
# 36           NaN  ...           https://ict.up.ac.th/personnel/major/ice
# 66           1.0  ...   http://itech.tru.ac.th/2014/?page=teacher&id=125
# 104          1.0  ...                                                NaN
# 108          1.0  ...  https://engineer.utcc.ac.th/?p=personel&uid=am...
# 151          1.0  ...  https://www.cpe.eng.cmu.ac.th/academicView.php...
# ...          ...  ...                                                ...
# 7135         NaN  ...  https://cvs.enit.kku.ac.th/cv/profile/123551/%...
# 7171         1.0  ...  https://www.spu.ac.th/fac/engineer/th/staff.ph...
# 7180         1.0  ...                                                NaN
# 7185         1.0  ...                                                NaN
# 7270         NaN  ...  https://scholar.google.com/citations?user=xsYO...
#
# [221 rows x 24 columns]

# %%
index_prefix_education = 2
index_prefix = 3
prefix_education = df_data_combine.columns[index_prefix_education]
prefix = df_data_combine.columns[index_prefix]

# %%
for index,row in df_duplicate_and_duplicate_name.iterrows():
  print(df_data_combine[(df_data_combine[first_name] == row[first_name]) & (df_data_combine[last_name] == row[last_name])][[prefix_education,prefix,first_name,last_name]])
# Out:
#      คำนำหน้า\nทางวิชาการ คำนำหน้า\nสถานภาพ First name Last name
# 25                อาจารย์               นาย          -         -
# 36     ผู้ช่วยศาสตราจารย์               นาย          -         -
# 42                อาจารย์            นางสาว          -         -
# 46                อาจารย์               นาย          -         -
# 47                อาจารย์               นาย          -         -
# ...                   ...               ...        ...       ...
# 7156              อาจารย์            นางสาว          -         -
# 7159          ศาสตราจารย์               นาย          -         -
# 7186              อาจารย์               นาย          -         -
# 7189              อาจารย์               นาย          -         -
# 7208              อาจารย์               นาย          -         -
#
# [1033 rows x 4 columns]
#    คำนำหน้า\nทางวิชาการ คำนำหน้า\nสถานภาพ First name Last name
# 65              อาจารย์               นาย        ITT     RANOK
# ...

# %%
df_data_combine[(df_data_combine[first_name]=='PUTTHIPONG')]
# Out:
#       Unnamed: 0  ...                            อ้างอิง (เว็บไซต์)
# 3125         NaN  ...  http://www.eng.src.ku.ac.th/user/putthipong/
# 3126         1.0  ...  http://www.eng.src.ku.ac.th/user/putthipong/
#
# [2 rows x 24 columns]

# %%
df_copy = pd.DataFrame(columns=df_data_combine.columns)

# %%
df_copy
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1, คำนำหน้า
# ทางวิชาการ, คำนำหน้า
# สถานภาพ, คำนำหน้า
# ตำแหน่งงาน, ชื่อ, นามสกุล, First name, Last name, เพศ, ชื่อเต็มมหาวิทยาลัย, คณะ, สาขา, จัหวัดที่ตั้งมหาวิทยาลัย, อีเมล, เบอร์โทร, ชื่อสถาบันศึกษาระดับปริญญาตรี, วุฒิการศึกษาระดับปริญญาตรี, ชื่อสถาบันศึกษาระดับปริญญาโท, วุฒิการศึกษาระดับปริญญาโท, ชื่อสถาบันศึกษาระดับปริญญาเอก, วุฒิการศึกษาระดับปริญญาเอก, ความเชี่ยวชาญ, อ้างอิง (เว็บไซต์)]
# Index: []

# %%
for index,row in df_duplicate_and_duplicate_name.iterrows():
  df_copy = df_copy.append(df_data_combine[(df_data_combine[first_name] == row[first_name]) & (df_data_combine[last_name] == row[last_name])])
  # print(df_data_combine[(df_data_combine[first_name] == row[first_name]) & (df_data_combine[last_name] == row[last_name])][[prefix_education,prefix,first_name,last_name]])

# %%
df_copy
# Out:
#       Unnamed: 0  ...                                 อ้างอิง (เว็บไซต์)
# 25           1.0  ...                                                NaN
# 36           NaN  ...           https://ict.up.ac.th/personnel/major/ice
# 42           NaN  ...  https://baac.reru.ac.th/index.php?option=com_c...
# 46           NaN  ...              https://finearts.dpu.ac.th/staff/3/20
# 47           NaN  ...  http://www.mct.rmutt.ac.th/aboutus/personnel-n...
# ...          ...  ...                                                ...
# 7180         1.0  ...                                                NaN
# 7184         NaN  ...  http://www.ce.kmitl.ac.th/faculty.php?action=v...
# 7185         1.0  ...                                                NaN
# 7267         NaN  ...  https://scholar.google.com/citations?user=xsYO...
# 7270         NaN  ...  https://scholar.google.com/citations?user=xsYO...
#
# [1474 rows x 24 columns]

# %%
df_copy[df_copy[first_name] != '-']
# Out:
#       Unnamed: 0  ...                                 อ้างอิง (เว็บไซต์)
# 65           NaN  ...   http://itech.tru.ac.th/2014/?page=teacher&id=125
# 66           1.0  ...   http://itech.tru.ac.th/2014/?page=teacher&id=125
# 103          NaN  ...  http://www.ce.kmitl.ac.th/faculty.php?action=v...
# 104          1.0  ...                                                NaN
# 107          NaN  ...  https://engineer.utcc.ac.th/?p=personel&uid=am...
# ...          ...  ...                                                ...
# 7180         1.0  ...                                                NaN
# 7184         NaN  ...  http://www.ce.kmitl.ac.th/faculty.php?action=v...
# 7185         1.0  ...                                                NaN
# 7267         NaN  ...  https://scholar.google.com/citations?user=xsYO...
# 7270         NaN  ...  https://scholar.google.com/citations?user=xsYO...
#
# [441 rows x 24 columns]

# %%
df_difference_prefix_education = pd.DataFrame(columns=df_data_combine.columns)
for index,row in df_duplicate_and_duplicate_name.iterrows():
  df_uniq = df_copy[(df_copy[first_name] == row[first_name]) & (df_copy[last_name] == row[last_name])]
  if len(df_uniq.groupby([prefix_education,first_name,last_name]))>1:
    df_difference_prefix_education = df_difference_prefix_education.append(df_uniq)

# %%
df_difference_prefix_education[df_difference_prefix_education[first_name] != '-']
# Out:
#       Unnamed: 0  ...                                 อ้างอิง (เว็บไซต์)
# 150          NaN  ...  https://www.researchgate.net/profile/Arnan_Sip...
# 151          1.0  ...  https://www.cpe.eng.cmu.ac.th/academicView.php...
# 327          NaN  ...                                                NaN
# 328          NaN  ...                                                NaN
# 470          NaN  ...  https://sites.google.com/udru.ac.th/electrical...
# 471          1.0  ...  https://sites.google.com/udru.ac.th/electrical...
# 1108         1.0  ...                 http://www.it.kmitl.ac.th/~sirion/
# 1109         NaN  ...                                                NaN
# 1112         1.0  ...   http://itech.tru.ac.th/2014/?page=teacher&id=127
# 1113         NaN  ...   http://itech.tru.ac.th/2014/?page=teacher&id=127
# 1561         1.0  ...   http://itech.tru.ac.th/2014/?page=teacher&id=146
# 1562         NaN  ...   http://itech.tru.ac.th/2014/?page=teacher&id=146
# ...

# %%
len(df_difference_prefix_education.groupby([first_name,last_name]))
# Out:
# 31

# %%
df_difference_prefix = pd.DataFrame(columns=df_data_combine.columns)
for index,row in df_duplicate_and_duplicate_name.iterrows():
  df_uniq = df_copy[(df_copy[first_name] == row[first_name]) & (df_copy[last_name] == row[last_name])]
  if len(df_uniq.groupby([prefix,first_name,last_name]))>1:
    df_difference_prefix = df_difference_prefix.append(df_uniq)

# %%
df_difference_prefix[df_difference_prefix[first_name] !='-']
# Out:
#       Unnamed: 0  ...                                 อ้างอิง (เว็บไซต์)
# 373          NaN  ...  http://www.ce.kmitl.ac.th/faculty.php?action=v...
# 374          1.0  ...                                                NaN
# 419          NaN  ...                                                  -
# 420          1.0  ...                                                  -
# 1338         NaN  ...  http://www.ce.kmitl.ac.th/faculty.php?action=v...
# 1339         1.0  ...                                                NaN
# 1683         NaN  ...  https://research.ku.ac.th/ku_resume/?idcode=48...
# 1684         1.0  ...  https://research.ku.ac.th/forest/Person.aspx?i...
# 2258         NaN  ...  http://www.ce.kmitl.ac.th/faculty.php?action=v...
# 2259         1.0  ...                                                NaN
# 3125         NaN  ...       http://www.eng.src.ku.ac.th/user/putthipong/
# 3126         1.0  ...       http://www.eng.src.ku.ac.th/user/putthipong/
# ...

# %%
len(df_difference_prefix.groupby([first_name,last_name]))
# Out:
# 16

# %% [markdown]
# ## สรุปผล เรื่องการ Duplicate (จะเน้นไปเรื่องชื่อ นามสกุล ภาษาอังกฤษที่ Duplicate)
#   - มีจำนวนคนที่ Uniq ตามชื่อและนามสกุลที่เป็นภาษาอังกฤษ 6051 คน
#   - คนที่มีการ Duplicate ทั้งหมดมีจำนวน 221 คนจาก 6051 คน
# 	- ปัญหาคำนำหน้าทางวิชาการไม่เหมือนกัน (มี 31 คนจาก 221 คน)
# 	- ปัญหานาย นางกับนางสาว และ - (มี 16 คนจาก 221 คน) จากการสังเกตุเพิ่มเติมคาดว่าการใส่คอลัมที่ชื่อว่า เพศ เกิดจาก การดูคอมลัมน์คำนำหน้า

# %% [markdown]
# # วิเคราะห์เรื่อง ชื่อสถาบันศึกษาระดับปริญญาตรี  โท เอก บางครั้งเป็นชื่อภาษาไทยบางครั้งเป็นชื่อภาษาอังกฤษ

# %%
df_data_combine
# Out:
#       Unnamed: 0  ...                                 อ้างอิง (เว็บไซต์)
# 0            NaN  ...  http://eng.pnu.ac.th/web/academic-staffs/hafis...
# 1            NaN  ...  http://eng.pnu.ac.th/web/academic-staffs/asst-...
# 2            NaN  ...  http://eng.pnu.ac.th/web/academic-staffs/hasun...
# 3            NaN  ...  http://eng.pnu.ac.th/web/academic-staffs/hassa...
# 4            NaN  ...                                                NaN
# ...          ...  ...                                                ...
# 7299         NaN  ...  https://www.krai.io/people,https://set.ait.ac....
# 7300         NaN  ...  https://repository.nida.ac.th/handle/662723737...
# 7301         NaN  ...  https://pdfs.semanticscholar.org/be4e/ef39fc48...
# 7302         NaN  ...  http://www.eng.au.edu/index.php/about/faculty-...
# 7303         NaN  ...                  https://me.eng.cmu.ac.th/staff/47
#
# [7304 rows x 24 columns]

# %%
education_bachelor_index = 16
education_bachelor = df_data_combine.columns[education_bachelor_index]
education_master_index = 18
education_master = df_data_combine.columns[education_master_index]
education_doctor_index = 20
education_doctor = df_data_combine.columns[education_doctor_index]

# %%
import re

def IsEnglish(word):
    reg = re.compile(r'[a-zA-Z0-9 .!?"-]+')
    if pd.notnull(word):
      if reg.match(word):
        return True
      else:
        return False
    else:
      return True

# %%
df_data_combine[educcation_bachelor]
# Out:
# 0       มหาวิทยาลัยนราธิวาสราชนครินทร์
# 1             มหาวิทยาลัยสงขลานครินทร์
# 2          มหาวิทยาลัยเทคโนโลยีสุรนารี
# 3                   มหาวิทยาลัยศรีปทุม
# 4                     วิทยาลัยครูสงขลา
#                      ...
# 7299           มหาวิทยาลัยยอนเซกรุงโซล
# 7300                                 -
# 7301                               NaN
# 7302             Assumption University
# 7303                                 -
# Name: ชื่อสถาบันศึกษาระดับปริญญาตรี, Length: 7304, dtype: object

# %%
education_bachelor_column_name = 'education_bachelor_english'
df_data_combine[education_bachelor_column_name] = df_data_combine[education_bachelor].apply(IsEnglish)

education_master_column_name = 'education_master_english'
df_data_combine[education_master_column_name] = df_data_combine[education_master].apply(IsEnglish)

education_doctor_column_name = 'education_doctor_english'
df_data_combine[education_doctor_column_name] = df_data_combine[education_doctor].apply(IsEnglish)

# %% [markdown]
# ## ปริญญาตรี

# %%
df_data_combine[[education_bachelor,education_bachelor_column_name]]
# Out:
#        ชื่อสถาบันศึกษาระดับปริญญาตรี  education_bachelor_english
# 0     มหาวิทยาลัยนราธิวาสราชนครินทร์                       False
# 1           มหาวิทยาลัยสงขลานครินทร์                       False
# 2        มหาวิทยาลัยเทคโนโลยีสุรนารี                       False
# 3                 มหาวิทยาลัยศรีปทุม                       False
# 4                   วิทยาลัยครูสงขลา                       False
# ...                              ...                         ...
# 7299         มหาวิทยาลัยยอนเซกรุงโซล                       False
# 7300                               -                        True
# 7301                             NaN                        True
# 7302           Assumption University                        True
# 7303                               -                        True
#
# [7304 rows x 2 columns]

# %%
#ไม่มีข้อมูลปริญญาตรี
df_data_combine[(df_data_combine[education_bachelor]=='-') | 
                (df_data_combine[education_bachelor].isna())]
# Out:
#       Unnamed: 0 Unnamed: 1  ... education_master_english education_doctor_english
# 11           NaN         AI  ...                     True                     True
# 12           NaN         IT  ...                     True                     True
# 21           NaN         AI  ...                     True                     True
# 28           NaN         IT  ...                     True                     True
# 30           NaN         IT  ...                    False                     True
# ...          ...        ...  ...                      ...                      ...
# 7289         NaN         IT  ...                     True                     True
# 7296         NaN         IT  ...                     True                     True
# 7300         NaN         AI  ...                     True                    False
# 7301         NaN         AI  ...                     True                     True
# ...

# %%
#มีข้อมูลปริญญาตรี
df_data_combine[~((df_data_combine[education_bachelor]=='-') | 
                (df_data_combine[education_bachelor].isna()))]
# Out:
#       Unnamed: 0 Unnamed: 1  ... education_master_english education_doctor_english
# 0            NaN         IT  ...                    False                     True
# 1            NaN         AI  ...                     True                     True
# 2            NaN         IT  ...                    False                     True
# 3            NaN         AI  ...                    False                     True
# 4            NaN         IT  ...                    False                     True
# ...          ...        ...  ...                      ...                      ...
# 7295         NaN         IT  ...                     True                     True
# 7297         NaN         IT  ...                     True                     True
# 7298         NaN         AI  ...                     True                     True
# 7299         NaN         AI  ...                     True                     True
# ...

# %%
df_have_bachelor = df_data_combine[~((df_data_combine[education_bachelor]=='-') | 
                (df_data_combine[education_bachelor].isna()))]

# %%
#ตรวจสอบว่ามีภาษาอังกฤษเท่าไหร่ ภาษาไทยเท่าไหร่
df_have_bachelor.groupby(education_bachelor_column_name).size()
# Out:
# education_bachelor_english
# False    4483
# True      904
# dtype: int64

# %% [markdown]
# ## ปริญญาโท

# %%
df_have_bachelor[[education_master,education_master_column_name]]
# Out:
#                     ชื่อสถาบันศึกษาระดับปริญญาโท  education_master_english
# 0     มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าพระนครเหนือ                     False
# 1      International Islamic University Malaysia                      True
# 2                    มหาวิทยาลัยเทคโนโลยีสุรนารี                     False
# 3              มหาวิทยาลัยอิสลามนานาชาติมาเลเซีย                     False
# 4                       มหาวิทยาลัยสงขลานครินทร์                     False
# ...                                          ...                       ...
# 7295          The State University of New Jersey                      True
# 7297       Massachusetts Institute of Technology                      True
# 7298         State University of Ghent, Belgium.                      True
# 7299                                MSTU, Moscow                      True
# 7302                       Assumption University                      True
#
# [5387 rows x 2 columns]

# %%
#ไม่มีข้อมูลปริญญาโท
df_data_combine[(df_data_combine[education_master]=='-') | 
                (df_data_combine[education_master].isna())]
# Out:
#       Unnamed: 0 Unnamed: 1  ... education_master_english education_doctor_english
# 11           NaN         AI  ...                     True                     True
# 12           NaN         IT  ...                     True                     True
# 21           NaN         AI  ...                     True                     True
# 28           NaN         IT  ...                     True                     True
# 34           NaN         IT  ...                     True                     True
# ...          ...        ...  ...                      ...                      ...
# 7280         NaN         IT  ...                     True                     True
# 7283         NaN         IT  ...                     True                     True
# 7300         NaN         AI  ...                     True                    False
# 7301         NaN         AI  ...                     True                     True
# ...

# %%
#มีข้อมูลปริญญาโท
df_data_combine[~((df_data_combine[education_master]=='-') | 
                (df_data_combine[education_master].isna()))]
# Out:
#       Unnamed: 0 Unnamed: 1  ... education_master_english education_doctor_english
# 0            NaN         IT  ...                    False                     True
# 1            NaN         AI  ...                     True                     True
# 2            NaN         IT  ...                    False                     True
# 3            NaN         AI  ...                    False                     True
# 4            NaN         IT  ...                    False                     True
# ...          ...        ...  ...                      ...                      ...
# 7296         NaN         IT  ...                     True                     True
# 7297         NaN         IT  ...                     True                     True
# 7298         NaN         AI  ...                     True                     True
# 7299         NaN         AI  ...                     True                     True
# ...

# %%
df_have_master = df_data_combine[~((df_data_combine[education_master]=='-') | 
                (df_data_combine[education_master].isna()))]

# %%
#ตรวจสอบว่ามีภาษาอังกฤษเท่าไหร่ ภาษาไทยเท่าไหร่
df_have_master.groupby(education_master_column_name).size()
# Out:
# education_master_english
# False    3685
# True     1656
# dtype: int64

# %% [markdown]
# ## ปริญญาเอก

# %%
df_data_combine[[education_doctor,education_doctor_column_name]]
# Out:
#                   ชื่อสถาบันศึกษาระดับปริญญาเอก  education_doctor_english
# 0                                             -                      True
# 1                                             -                      True
# 2                                             -                      True
# 3     International Islamic University Malaysia                      True
# 4                                             -                      True
# ...                                         ...                       ...
# 7299          Moscow State Technical University                      True
# 7300               สถาบันบัณฑิตพัฒนบริหารศาสตร์                     False
# 7301                                        NaN                      True
# 7302  Dalhousie University, Halifax, NS, Canada                      True
# 7303                                          -                      True
#
# [7304 rows x 2 columns]

# %%
#ไม่มีข้อมูลปริญญาเอก
df_data_combine[(df_data_combine[education_doctor]=='-') | 
                (df_data_combine[education_doctor].isna())]
# Out:
#       Unnamed: 0 Unnamed: 1  ... education_master_english education_doctor_english
# 0            NaN         IT  ...                    False                     True
# 1            NaN         AI  ...                     True                     True
# 2            NaN         IT  ...                    False                     True
# 4            NaN         IT  ...                    False                     True
# 6            NaN         IT  ...                    False                     True
# ...          ...        ...  ...                      ...                      ...
# 7273         NaN         IT  ...                     True                     True
# 7275         NaN         IT  ...                     True                     True
# 7294         NaN         IT  ...                     True                     True
# 7301         NaN         AI  ...                     True                     True
# ...

# %%
#มีข้อมูลปริญญาเอก
df_data_combine[~((df_data_combine[education_doctor]=='-') | 
                (df_data_combine[education_doctor].isna()))]
# Out:
#       Unnamed: 0 Unnamed: 1  ... education_master_english education_doctor_english
# 3            NaN         AI  ...                    False                     True
# 5            NaN         IT  ...                     True                    False
# 7            NaN         IT  ...                    False                    False
# 10           NaN         IT  ...                    False                    False
# 11           NaN         AI  ...                     True                     True
# ...          ...        ...  ...                      ...                      ...
# 7297         NaN         IT  ...                     True                     True
# 7298         NaN         AI  ...                     True                     True
# 7299         NaN         AI  ...                     True                     True
# 7300         NaN         AI  ...                     True                    False
# ...

# %%
df_have_doctor = df_data_combine[~((df_data_combine[education_doctor]=='-') | 
                (df_data_combine[education_doctor].isna()))]

# %%
#ตรวจสอบว่ามีภาษาอังกฤษเท่าไหร่ ภาษาไทยเท่าไหร่
df_have_doctor.groupby(education_doctor_column_name).size()
# Out:
# education_doctor_english
# False    1357
# True     2215
# dtype: int64

# %% [markdown]
# ## สรุปเรื่อง ชื่อสถาบันศึกษาระดับปริญญาตรี  โท เอก บางครั้งเป็นชื่อภาษาไทยบางครั้งเป็นชื่อภาษาอังกฤษ
# - จาก Row ทั้งหมด 7304 row
# - มีข้อมูลสถาบันศึกษาระดับปริญญาตรีทั้งหมด 5387
#     - มีชื่อที่เป็นภาษาไทย 4483
#     - มีชื่อที่เป็นภาษาอังกฤษ 904
# - มีข้อมูลสถาบันศึกษาระดับปริญญาโททั้งหมด 5341
#     - มีชื่อที่เป็นภาษาไทย 3685
#     - มีชื่อที่เป็นภาษาอังกฤษ 1656
# - มีข้อมูลสถาบันศึกษาระดับปริญญาเอกทั้งหมด 3572
#     - มีชื่อที่เป็นภาษาไทย 1357
#     - มีชื่อที่เป็นภาษาอังกฤษ 2215

# %% [markdown]
# # สรุปทั้งหมด
# **สิ่งที่พบ**
# - ชื่อ Duplicate กัน
# - บางครั้งเป็น - บางครั้งเป็นค่า NaN ในการระบุว่าไม่มีข้อมูล
# - ชื่อสถาบันศึกษาระดับปริญญาตรี  โท เอก บางครั้งเป็นชื่อภาษาไทยบางครั้งเป็นชื่อภาษาอังกฤษ
#
# - วุฒิการศึกษาระดับปริญญาตรี โท เอก บางครั้งเป็นชื่อย่อ บางครั้งเป็นชื่อเต็ม และบางครั้งเป็นภาษาอังกฤษ และอาจมีคำอื่นเข้ามาเช่น "กำลังศึกษา" , "ลา", "ปริญญาเอก"

# %% [markdown]
# ## สรุปผล เรื่องการ Duplicate (จะเน้นไปเรื่องชื่อ นามสกุล ภาษาอังกฤษที่ Duplicate)
#   - มีจำนวนคนที่ Uniq ตามชื่อและนามสกุลที่เป็นภาษาอังกฤษ 6051 คน
#   - คนที่มีการ Duplicate ทั้งหมดมีจำนวน 221 คนจาก 6051 คน
# 	- ปัญหาคำนำหน้าทางวิชาการไม่เหมือนกัน (มี 31 คนจาก 221 คน)
# 	- ปัญหานาย นางกับนางสาว และ - (มี 16 คนจาก 221 คน) จากการสังเกตุเพิ่มเติมคาดว่าการใส่คอลัมที่ชื่อว่า เพศ เกิดจาก การดูคอมลัมน์คำนำหน้า

# %% [markdown]
# ## สรุปเรื่อง ชื่อสถาบันศึกษาระดับปริญญาตรี  โท เอก บางครั้งเป็นชื่อภาษาไทยบางครั้งเป็นชื่อภาษาอังกฤษ
# - จาก Row ทั้งหมด 7304 row
# - มีข้อมูลสถาบันศึกษาระดับปริญญาตรีทั้งหมด 5387
#     - มีชื่อที่เป็นภาษาไทย 4483
#     - มีชื่อที่เป็นภาษาอังกฤษ 904
# - มีข้อมูลสถาบันศึกษาระดับปริญญาโททั้งหมด 5341
#     - มีชื่อที่เป็นภาษาไทย 3685
#     - มีชื่อที่เป็นภาษาอังกฤษ 1656
# - มีข้อมูลสถาบันศึกษาระดับปริญญาเอกทั้งหมด 3572
#     - มีชื่อที่เป็นภาษาไทย 1357
#     - มีชื่อที่เป็นภาษาอังกฤษ 2215
